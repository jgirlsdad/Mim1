# %%
import pandas as pd

# %%
! dir data
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 48FA-D8E0
#
#  Directory of C:\Users\CoJoe\Documents\MiM\P2\Mim1\data
#
# 12/20/2022  05:00 PM    <DIR>          .
# 12/21/2022  03:50 PM    <DIR>          ..
# 12/20/2022  02:18 PM         3,974,421 adult.data.csv
#                1 File(s)      3,974,421 bytes
#                2 Dir(s)  884,004,306,944 bytes free

# %%
df = pd.read_csv("data/adult.data.csv")
df.head()
# Out:
#    age           job type      id      degree  yrs employed  \
# 0   39          State-gov   77516   Bachelors            13
# 1   50   Self-emp-not-inc   83311   Bachelors            13
# 2   38            Private  215646     HS-grad             9
# 3   53            Private  234721        11th             7
# 4   28            Private  338409   Bachelors            13
#
#         married status          spouse job        fam stat    race   gender  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    col1  col2  col3         country sal range
# 0  2174     0    40   United-States     <=50K
# 1     0     0    13   United-States     <=50K
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   job type        32561 non-null  object
#  2   id              32561 non-null  int64
#  3   degree          32561 non-null  object
#  4   yrs employed    32561 non-null  int64
#  5   married status  32561 non-null  object
#  6   spouse job      32561 non-null  object
#  7   fam stat        32561 non-null  object
#  8   race            32561 non-null  object
#  9   gender          32561 non-null  object
#  10  col1            32561 non-null  int64
#  11  col2            32561 non-null  int64
#  12  col3            32561 non-null  int64
#  13  country         32561 non-null  object
#  14  sal range       32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.describe()
# Out:
#                 age            id  yrs employed          col1          col2  \
# count  32561.000000  3.256100e+04  32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05     10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05      2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04      1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05      9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05     10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05     12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06     16.000000  99999.000000   4356.000000
#
#                col3
# count  32561.000000
# mean      40.437456
# std       12.347429
# min        1.000000
# 25%       40.000000
# 50%       40.000000
# 75%       45.000000
# max       99.000000

# %%
for col in df.columns:
    if df[col].nunique() < 45:
        print(col)
        print(df[col].value_counts()) 
        print("---------------------------")
# Out:
# job type
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1298
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: job type, dtype: int64
# ---------------------------
# degree
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5355
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           333
#  1st-4th           168
#  Preschool          51
# Name: degree, dtype: int64
# ---------------------------
# yrs employed
# 9     10501
# 10     7291
# 13     5355
# 14     1723
# 11     1382
# 7      1175
# 12     1067
# 6       933
# 4       646
# 15      576
# 5       514
# 8       433
# 16      413
# ...

# %%
df.groupby("gender").mean()
# Out:
#                age             id  yrs employed         col1        col2  \
# gender
#  Female  36.858230  185746.311206     10.035744   568.410547   61.187633
#  Male    39.433547  191771.449013     10.102891  1329.370078  100.213309
#
#               col3
# gender
#  Female  36.410361
#  Male    42.428086

# %%
df.groupby("gender").mean().plot.bar(y="age")
# Out:
# <AxesSubplot:xlabel='gender'>

# %%
df.groupby("gender").count().plot.bar(y="age")
# Out:
# <AxesSubplot:xlabel='gender'>

# %%
df.groupby("degree").mean()
# Out:
#                      age             id  yrs employed          col1  \
# degree
#  10th          37.429796  196832.465166           6.0    404.574491
#  11th          32.355745  194928.077447           7.0    215.097872
#  12th          32.000000  199097.508083           8.0    284.087760
#  1st-4th       46.142857  239303.000000           2.0    125.875000
#  5th-6th       42.885886  232448.333333           3.0    176.021021
#  7th-8th       48.445820  188079.171827           4.0    233.939628
#  9th           41.060311  202485.066148           5.0    342.089494
#  Assoc-acdm    37.381443  193424.093721          12.0    640.399250
#  Assoc-voc     38.553546  181936.016643          11.0    715.051375
#  Bachelors     38.904949  188055.914846          13.0   1756.299533
#  Doctorate     47.702179  186698.760291          16.0   4770.145278
#  HS-grad       38.974479  189538.739739           9.0    576.800114
#  Masters       44.049913  179852.362739          14.0   2562.563552
# ...

# %%
df.groupby("degree").mean().sort_values(by="yrs employed",ascending=False)
# Out:
#                      age             id  yrs employed          col1  \
# degree
#  Doctorate     47.702179  186698.760291          16.0   4770.145278
#  Prof-school   44.746528  185663.706597          15.0  10414.416667
#  Masters       44.049913  179852.362739          14.0   2562.563552
#  Bachelors     38.904949  188055.914846          13.0   1756.299533
#  Assoc-acdm    37.381443  193424.093721          12.0    640.399250
#  Assoc-voc     38.553546  181936.016643          11.0    715.051375
#  Some-college  35.756275  188742.922370          10.0    598.824167
#  HS-grad       38.974479  189538.739739           9.0    576.800114
#  12th          32.000000  199097.508083           8.0    284.087760
#  11th          32.355745  194928.077447           7.0    215.097872
#  10th          37.429796  196832.465166           6.0    404.574491
#  9th           41.060311  202485.066148           5.0    342.089494
#  7th-8th       48.445820  188079.171827           4.0    233.939628
# ...

# %%
df.groupby("degree").mean().sort_values(by="yrs employed",ascending=False).plot.bar(y="yrs employed")
# Out:
# <AxesSubplot:xlabel='degree'>

# %%
df.groupby("married status").mean()
# Out:
#                               age             id  yrs employed         col1  \
# married status
#  Divorced               43.041639  185802.790457     10.030385   728.414810
#  Married-AF-spouse      32.478261  188165.565217     10.173913   432.652174
#  Married-civ-spouse     43.247596  186763.172877     10.320646  1764.859509
#  Married-spouse-absent  40.578947  193141.760766      9.308612   653.983254
#  Never-married          28.150988  195383.308996      9.962464   376.588318
#  Separated              39.354146  206444.325854      9.293659   535.568780
#  Widowed                58.975831  174159.042296      9.093656   571.071501
#
#                               col2       col3
# married status
#  Divorced                64.600720  41.246680
#  Married-AF-spouse        0.000000  41.130435
#  Married-civ-spouse     122.439103  43.284856
#  Married-spouse-absent   57.779904  39.669856
#  Never-married           52.345502  36.939998
#  Separated               58.110244  39.301463
# ...

# %%
df.groupby("married status").mean().sort_values(by="age",ascending=False).plot.bar(y="age")
# Out:
# <AxesSubplot:xlabel='married status'>

# %%
df.groupby(["degree","married status"]).mean()
# Out:
#                                             age             id  yrs employed  \
# degree        married status
#  10th          Divorced               44.133333  201738.950000           6.0
#                Married-civ-spouse     46.126074  199193.647564           6.0
#                Married-spouse-absent  42.000000  168431.066667           6.0
#                Never-married          23.961219  195238.570637           6.0
#                Separated              39.530612  211271.938776           6.0
# ...                                         ...            ...           ...
#  Some-college  Married-civ-spouse     42.210433  186734.132718          10.0
#                Married-spouse-absent  37.289474  187647.236842          10.0
#                Never-married          25.677804  192552.036481          10.0
#                Separated              38.086364  203498.631818          10.0
#                Widowed                57.523256  162819.540698          10.0
#
# ...

# %%
new = df.groupby(["married status","degree"],as_index=False).mean()

# %%
new.head()
# Out:
#   married status    degree        age             id  yrs employed  \
# 0       Divorced      10th  44.133333  201738.950000           6.0
# 1       Divorced      11th  41.230769  199077.784615           7.0
# 2       Divorced      12th  41.333333  178652.692308           8.0
# 3       Divorced   1st-4th  62.700000  204961.000000           2.0
# 4       Divorced   5th-6th  53.700000  235120.500000           3.0
#
#          col1        col2       col3
# 0  145.666667   13.283333  40.808333
# 1  203.369231   56.161538  40.023077
# 2    0.000000   57.897436  39.692308
# 3    0.000000    0.000000  32.800000
# 4  324.850000  210.750000  38.900000

# %%
new.loc[new["married status"] == "Widowed",:]
# Out:
# Empty DataFrame
# Columns: [married status, degree, age, id, yrs employed, col1, col2, col3]
# Index: []

# %%
new["married status"].value_counts()
# Out:
#  Divorced                 16
#  Married-civ-spouse       16
#  Married-spouse-absent    16
#  Never-married            16
#  Separated                16
#  Widowed                  16
#  Married-AF-spouse         5
# Name: married status, dtype: int64

# %%
new["married status"]
# Out:
# 0       Divorced
# 1       Divorced
# 2       Divorced
# 3       Divorced
# 4       Divorced
#          ...
# 96       Widowed
# 97       Widowed
# 98       Widowed
# 99       Widowed
# 100      Widowed
# Name: married status, Length: 101, dtype: object
